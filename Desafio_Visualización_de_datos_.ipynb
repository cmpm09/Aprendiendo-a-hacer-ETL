# %% [markdown]
# <a href="https://colab.research.google.com/github/cmpm09/Aprendiendo-a-hacer-ETL/blob/Visualizaci%C3%B3n/Desafio_Visualizaci%C3%B3n_de_datos_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Desafío 1: comparando tendencias migratorias

# %% [markdown]
# Crea un gráfico de líneas comparando los números de inmigrantes de Brasil y Argentina a Canadá, los dos países más grandes de Sudamérica.
#
# Explora las diversas posibilidades y recuerda los elementos esenciales de un gráfico: título, etiquetas en los ejes x e y y las marcas del eje x, que deben definirse cada 5 años.
#
# Además, tendrás que descubrir cómo agregar una leyenda para poder identificar la línea de cada país. Siguiendo estas instrucciones, habrás construido un gráfico sólido que te permitirá un análisis significativo y profundo.

# %%
import pandas as pd
df = pd.read_csv('/content/inmigrantes_canada.csv')
df.set_index('Pais', inplace = True)
df.head()
# Out:
#                 Continente           Region  1980  1981  1982  1983  1984  \
# Pais
# Afganistán            Asia      Sur de Asia    16    39    39    47    71
# Albania             Europa    Sur de Europa     1     0     0     0     0
# Argelia             África  Norte de África    80    67    71    69    63
# Samoa Americana    Oceanía        Polinesia     0     1     0     0     0
# Andorra             Europa    Sur de Europa     0     0     0     0     0
#
#                  1985  1986  1987  ...  2005  2006  2007  2008  2009  2010  \
# Pais                               ...
# Afganistán        340   496   741  ...  3436  3009  2652  2111  1746  1758
# Albania             0     1     2  ...  1223   856   702   560   716   561
# Argelia            44    69   132  ...  3626  4807  3623  4005  5393  4752
# Samoa Americana     0     0     1  ...     0     1     0     0     0     0
# Andorra             0     2     0  ...     0     1     1     0     0     0
#
#                  2011  2012  2013  Total
# Pais
# Afganistán       2203  2635  2004  58639
# Albania           539   620   603  15699
# Argelia          4325  3774  4331  69439
# Samoa Americana     0     0     0      6
# Andorra             0     1     1     15
#
# [5 rows x 37 columns]

# %%
anos = list(map(str, range(1980, 2014)))

argentina = df.loc['Argentina', anos]
brasil = df.loc['Brasil', anos]

# %%
col_dict = {'Año':argentina.index.tolist(),
            'Argentina':argentina.values.tolist(),
            'Brasil':brasil.values.tolist()}

# %%
datos_col = pd.DataFrame(col_dict)
datos_col.tail()
# Out:
#      Año  Argentina  Brasil
# 29  2009        467    2509
# 30  2010        459    2598
# 31  2011        278    1508
# 32  2012        263    1642
# 33  2013        282    1714

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(datos_col['Año'], datos_col['Brasil'], label='Brasil')
plt.plot(datos_col['Año'], datos_col['Argentina'], label='Argentina')
plt.title('Inmigración de Brasil y Argentina a Canadá')
plt.xlabel('Año')
plt.ylabel('Número de Inmigrantes')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.legend()
plt.show()

# %% [markdown]
# #Desafío 2: visualizando datos de ventas de tiendas diferentes

# %% [markdown]
# Trabajas como Analista de Datos en una empresa minorista y te asignaron la tarea de crear una figura con subgráficos que muestre la variación en el número de ventas en cuatro tiendas diferentes a lo largo de un año. La gerencia de la empresa necesita visualizar claramente las tendencias de ventas en cada tienda, para que puedan tomar decisiones estratégicas sobre inventarios y acciones de marketing. Para ello, debes crear cuatro subgráficos dispuestos en dos filas y dos columnas, donde cada subgráfico represente una tienda diferente. En este desafío, cada subgráfico debe presentar un gráfico de líneas que muestre la variación del número de ventas a lo largo de los meses del año.
#
# ¡Ahora es el momento de mostrar tus habilidades en análisis de datos y visualización! Para crear el DataFrame con el número de ventas de las tiendas y crear la figura, utiliza la siguiente información:

# %%
tiendas = ['A', 'B', 'C', 'D']
ventas_2022 = {'Ene': [100, 80, 150, 50],
    'Feb': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abr': [180, 110, 230, 90],
    'May': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Sep': [240, 160, 290, 130],
    'Oct': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dec': [300, 350, 400, 250]}

# %% [markdown]
# Consejo: Para facilitar la creación de los subgráficos, puedes definir la columna "tiendas" como índice del DataFrame y utilizar la propiedad loc de la biblioteca Pandas para trazar cada una de las tiendas.

# %%
df_tiendas = pd.DataFrame(ventas_2022, index=tiendas)
df_tiendas
# Out:
#    Ene  Feb  Mar  Abr  May  Jun  Jul  Ago  Sep  Oct  Nov  Dec
# A  100  120  150  180  220  230  250  260  240  220  400  300
# B   80   90  100  110  190  150  170  180  160  140  220  350
# C  150  170  200  230  350  280  300  310  290  270  350  400
# D   50   60   80   90  200  120  140  150  130  110  190  250

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 7))
plt.subplots_adjust(wspace=0.3, hspace=0.4)
fig.suptitle('Ventas en el período de enero a diciembre de 2022 en las tiendas A, B, C y D')

axs[0, 0].plot(df_tiendas.loc['A'])
axs[0, 0].set_title('Ventas en la tienda A')

axs[0, 1].plot(df_tiendas.loc['B'])
axs[0, 1].set_title('Ventas en la tienda B')

axs[1, 0].plot(df_tiendas.loc['C'])
axs[1, 0].set_title('Ventas en la tienda C')

axs[1, 1].plot(df_tiendas.loc['D'])
axs[1, 1].set_title('Ventas en la tienda D')

ymin = 0
ymax = 450

for ax in axs.ravel():
  ax.set_ylim(ymin, ymax)


for ax in axs.flat:
    ax.set_xlabel('Mes')
    ax.set_ylabel('Número de ventas')
    ax.grid()

plt.show()

# %% [markdown]
# # Desafío 3: personalizando los subplots con los datos de ventas de tiendas diferentes

# %% [markdown]
# Algunas ideas de personalización que puedes explorar son:
#
# - Cambiar la posición de los títulos de los subgráficos a la izquierda.
# - Aumentar el tamaño de la fuente del título general de la figura para resaltarlo.
# - Aumentar el tamaño de los títulos y etiquetas de los ejes de los subgráficos.
# - Hacer que las líneas sean más gruesas.
# - Cambiar el color de las líneas de cada tienda para diferenciarlas aún más.
#
# Y aquí va otro consejo: puedes reducir el tamaño del código utilizando el comando `for i, ax in enumerate(axs.flat):`, que permite un bucle que itera sobre todos los subgráficos de la figura. Dentro de este bucle, puedes pasar las funciones `plot, set_title, set_xlabel, set_ylabel`, y así sucesivamente...

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 7))
plt.subplots_adjust(wspace=0.3, hspace=0.4)
fig.suptitle('Ventas en el período de enero a diciembre de 2022 en las tiendas A, B, C y D', fontsize=18)

axs[0, 0].plot(df_tiendas.loc['A'],lw=2.5, marker = 'o',color = 'orange')
axs[0, 0].set_title('Ventas en la tienda A', loc='left', fontsize=14)

axs[0, 1].plot(df_tiendas.loc['B'],lw=2.5, marker = 'o',color = 'green')
axs[0, 1].set_title('Ventas en la tienda B', loc='left', fontsize=14)

axs[1, 0].plot(df_tiendas.loc['C'],lw=2.5, marker = 'o',color = 'red')
axs[1, 0].set_title('Ventas en la tienda C', loc='left', fontsize=14)

axs[1, 1].plot(df_tiendas.loc['D'],lw=2.5, marker = 'o',color = 'blue')
axs[1, 1].set_title('Ventas en la tienda D', loc='left', fontsize=14)

ymin = 0
ymax = 450

for ax in axs.ravel():
  ax.set_ylim(ymin, ymax)


for ax in axs.flat:
    ax.set_xlabel('Mes', fontsize=12)
    ax.set_ylabel('Número de ventas', fontsize=12)
    ax.grid()

plt.show()

# %% [markdown]
# Opinión del instructor

# %%
# Crear la figura y los subgráficos
fig, axs = plt.subplots(2, 2, figsize=(14, 8))

# Ajustar los espaciados entre los subgráficos
plt.subplots_adjust(wspace=0.3, hspace=0.4)

# Agregar un título general a los subgráficos
fig.suptitle('Ventas en el periodo de enero a diciembre de 2022 en las tiendas A, B, C y D', fontsize=20)

# Lista de colores
colores = ['darkviolet', 'green', 'darkblue', 'coral']

# Bucle para trazar y personalizar los subgráficos
for i, ax in enumerate(axs.flat):
    ax.plot(df_tiendas.loc[df_tiendas.index[i]], color=colores[i], lw=3)
    ax.set_title(f'Ventas en la tienda {df_tiendas.index[i]}', loc='left', fontsize=16)
    ax.set_xlabel('Mes', fontsize=14)
    ax.set_ylabel('Número de ventas', fontsize=14)
    ax.tick_params(labelsize=12)
    ax.grid(color='lightgrey')

# %% [markdown]
# #Desafío 4 : creando un gráfico de líneas con Seaborn

# %% [markdown]
# En esta etapa, tu desafío es crear una figura que muestre las tendencias de inmigración de los 4 mayores países de América Latina: Brasil, Argentina, Perú y Colombia. A través de esta creación, puedes explorar diversas posibilidades y mostrar de manera atractiva tu proceso de desarrollo. Y no nos olvidemos de las indicaciones. Esta figura debe tener una línea para cada país, título, etiquetas en los ejes, colores apropiados, un tema de la biblioteca Seaborn y una leyenda. Por lo tanto, piensa en cuestiones de accesibilidad, como el tamaño de las fuentes y el grosor de las líneas. Es importante elegir colores adecuados que no causen fatiga visual o dificulten la lectura de la información. Además, el tamaño de las fuentes debe ser lo suficientemente legible para que las personas puedan interpretar los datos fácilmente.

# %% [markdown]
# Consejo: para elegir la paleta de colores, también puedes consultar la documentación de la biblioteca Matplotlib. Seaborn utiliza los colormaps de Matplotlib por defecto, además de ofrecer sus propias paletas de colores. Para aplicar una paleta de colores a todas las líneas de la figura, puedes usar la función sns.set_palette() y pasarle el nombre de la paleta elegida.

# %%
import seaborn as sns

# %%
sns.set_theme()
sns.set_palette('rocket')

fig, ax = plt.subplots(figsize=(12, 5))

ax = sns.lineplot(x=anos, y=df.loc['Brasil', anos], label='Brasil', lw=3, marker = 'o')
ax = sns.lineplot(x=anos, y=df.loc['México', anos], label='México', lw=3, marker = 'o')
ax = sns.lineplot(x=anos, y=df.loc['Perú', anos], label='Perú', lw=3, marker = 'o')
ax = sns.lineplot(x=anos, y=df.loc['Colombia', anos], label='Colombia', lw=3, marker = 'o')


ax.set_title('Inmigración de los países más grandes de Latinoamérica\na Canadá de 1980 a 2013', loc='left', fontsize=18)

ax.set_xlabel('Año', fontsize=14)
ax.set_ylabel('Número de Inmigrantes', fontsize=14)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.legend(title='Países', loc='upper left', bbox_to_anchor=(1, 1))


plt.show()

# %% [markdown]
# #Desafío 5: creando una animación para comparar diferentes datos

# %%
datos_col.tail()
# Out:
#      Año  Argentina  Brasil
# 29  2009        467    2509
# 30  2010        459    2598
# 31  2011        278    1508
# 32  2012        263    1642
# 33  2013        282    1714

# %%
import plotly.graph_objs as go

# Creando una figura
fig = go.Figure()

# Agregando la línea con los datos de Brasil
fig.add_trace(
    go.Scatter(x=[datos_col['Año'].iloc[0]], y=[datos_col['Brasil'].iloc[0]], mode='lines', name='Inmigrantes de Brasil', line=dict(width=4))
)

# Agregando la línea con los datos de Argentina
fig.add_trace(
    go.Scatter(x=[datos_col['Año'].iloc[0]], y=[datos_col['Argentina'].iloc[0]], mode='lines', name='Inmigrantes de Argentina', line=dict(width=4))
)

# Definiendo las configuraciones de diseño
fig.update_layout(
    title=dict(
        text='<b>Inmigración de Brasil y Argentina a Canadá en el período de 1980 a 2013</b>',
        x=0.1,
        font=dict(size=18)
    ),
    xaxis=dict(range=[1980, 2013], autorange=False, title='<b>Año</b>'),
    yaxis=dict(range=[0, 3000], autorange=False, title='<b>Número de inmigrantes</b>'),
    updatemenus=[dict(
        type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}]
        )]
    )],
    width=1200,
    height=600
)

# Definiendo las configuraciones de animación
frames = []
for i in range(len(datos_col)):
    frame_data = [
        go.Scatter(x=datos_col['Año'].iloc[:i+1], y=datos_col['Brasil'].iloc[:i+1]),
        go.Scatter(x=datos_col['Año'].iloc[:i+1], y=datos_col['Argentina'].iloc[:i+1])
    ]
    frame = go.Frame(data=frame_data)
    frames.append(frame)
fig.frames = frames

# Mostrando la figura

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4eae5926-c535-4754-b9d8-7948f95e82cf" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4eae5926-c535-4754-b9d8-7948f95e82cf")) {                    Plotly.newPlot(                        "4eae5926-c535-4754-b9d8-7948f95e82cf",                        [{"line":{"width":4},"mode":"lines","name":"Inmigrantes de Brasil","x":["1980"],"y":[211],"type":"scatter"},{"line":{"width":4},"mode":"lines","name":"Inmigrantes de Argentina","x":["1980"],"y":[368],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay" ...
